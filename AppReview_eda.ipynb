# %% [markdown]
# ## Mobile Application Review

# %%
import pandas as pd
from IPython.display import Image

# %% [markdown]
# - all_detailed = "d"
# - newest_reviews = "r"
# - Education = "edu"
# - Finance = "fin"
# - Game Action = "ga"
# - Musica and Audio = "ma"
# - Entertainment = "ent"
# - Family = "fa"
# - Lifestyle = "life"
# - Health and Fitness = "hf"

# %% [markdown]
# ### 2019 March

# %%
#Education_0308
d_edu_0308 = pd.read_csv("Dataset/2019-03-08_TOP_FREE_EDUCATION_APPS/2019-03-08_all_detailed_TOP_FREE_EDUCATION_apps.csv")
r_edu_0308 = pd.read_csv("Dataset/2019-03-08_TOP_FREE_EDUCATION_APPS/2019-03-08_newest_reviews_TOP_FREE_EDUCATION_apps.csv")
d_edu_0308['Category'] = 'Education'
r_edu_0308['Category'] = 'Education'
#Finance_0308
d_fin_0308 = pd.read_csv("Dataset/2019-03-08_TOP_FREE_FINANCE_APPS/2019-03-08_all_detailed_TOP_FREE_FINANCE_apps.csv")
r_fin_0308 = pd.read_csv("Dataset/2019-03-08_TOP_FREE_FINANCE_APPS/2019-03-08_newest_reviews_TOP_FREE_FINANCE_apps.csv")
d_fin_0308['Category'] = 'Finance'
r_fin_0308['Category'] = 'Finance'
#Game_Action_0308
d_ga_0308 = pd.read_csv("Dataset/2019-03-08_TOP_FREE_GAME_ACTION_APPS/2019-03-08_all_detailed_TOP_FREE_GAME_ACTION_apps.csv")
r_ga_0308 = pd.read_csv("Dataset/2019-03-08_TOP_FREE_GAME_ACTION_APPS/2019-03-08_newest_reviews_TOP_FREE_GAME_ACTION_apps.csv")
d_ga_0308['Category'] = 'Game_Action'
r_ga_0308['Category'] = 'Game_Action'

#Music_Audio_0309
d_ma_0309 = pd.read_csv("Dataset/2019-03-09_TOP_FREE_MUSIC_AND_AUDIO_APPS/2019-03-09_all_detailed_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
r_ma_0309 = pd.read_csv("Dataset/2019-03-09_TOP_FREE_MUSIC_AND_AUDIO_APPS/2019-03-09_newest_reviews_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
d_ma_0309['Category'] = 'Music_Audio'
r_ma_0309['Category'] = 'Music_Audio'

#Entertainment_0313
d_ent_0313 = pd.read_csv("Dataset/2019-03-13_TOP_FREE_ENTERTAINMENT_APPS/2019-03-13_all_detailed_TOP_FREE_ENTERTAINMENT_apps.csv")
r_ent_0313 = pd.read_csv("Dataset/2019-03-13_TOP_FREE_ENTERTAINMENT_APPS/2019-03-13_newest_reviews_TOP_FREE_ENTERTAINMENT_apps.csv")
d_ent_0313['Category'] = 'Entertainment'
r_ent_0313['Category'] = 'Entertainment'
#Family_0313
d_fa_0313 = pd.read_csv("Dataset/2019-03-13_TOP_FREE_FAMILY_APPS/2019-03-13_all_detailed_TOP_FREE_FAMILY_apps.csv")
r_fa_0313 = pd.read_csv("Dataset/2019-03-13_TOP_FREE_FAMILY_APPS/2019-03-13_newest_reviews_TOP_FREE_FAMILY_apps.csv")
d_fa_0313['Category'] = 'Family'
r_fa_0313['Category'] = 'Family'
#Lifestyle_0313
d_life_0313 = pd.read_csv("Dataset/2019-03-13_TOP_FREE_LIFESTYLE_APPS/2019-03-13_all_detailed_TOP_FREE_LIFESTYLE_apps.csv")
r_life_0313 = pd.read_csv("Dataset/2019-03-13_TOP_FREE_LIFESTYLE_APPS/2019-03-13_newest_reviews_TOP_FREE_LIFESTYLE_apps.csv")
d_life_0313['Category'] = 'Lifestyle'
r_life_0313['Category'] = 'Lifestyle'

#Health_Fitness_0316
d_hf_0316 = pd.read_csv("Dataset/2019-03-16_TOP_FREE_HEALTH_AND_FITNESS_APPS/2019-03-16_all_detailed_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
r_hf_0316 = pd.read_csv("Dataset/2019-03-16_TOP_FREE_HEALTH_AND_FITNESS_APPS/2019-03-16_newest_reviews_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
d_hf_0316['Category'] = 'Health_Fitness'
r_hf_0316['Category'] = 'Health_Fitness'

#Eductoin_0324
d_edu_0324 = pd.read_csv("Dataset/2019-03-24/2019-03-24_TOP_FREE_EDUCATION_APPS/2019-03-24_all_detailed_TOP_FREE_EDUCATION_apps.csv")
r_edu_0324 = pd.read_csv("Dataset/2019-03-24/2019-03-24_TOP_FREE_EDUCATION_APPS/2019-03-24_newest_reviews_TOP_FREE_EDUCATION_apps.csv")
d_edu_0324['Category'] = 'Education'
r_edu_0324['Category'] = 'Education'
#Entertainment_0324
d_ent_0324 = pd.read_csv("Dataset/2019-03-24/2019-03-24_TOP_FREE_ENTERTAINMENT_APPS/2019-03-24_all_detailed_TOP_FREE_ENTERTAINMENT_apps.csv")
r_ent_0324 = pd.read_csv("Dataset/2019-03-24/2019-03-24_TOP_FREE_ENTERTAINMENT_APPS/2019-03-24_newest_reviews_TOP_FREE_ENTERTAINMENT_apps.csv")
d_ent_0324['Category'] = 'Entertainment'
r_ent_0324['Category'] = 'Entertainment'
#Family_0324
d_fa_0324 = pd.read_csv("Dataset/2019-03-24/2019-03-24_TOP_FREE_FAMILY_APPS/2019-03-24_all_detailed_TOP_FREE_FAMILY_apps.csv")
r_fa_0324 = pd.read_csv("Dataset/2019-03-24/2019-03-24_TOP_FREE_FAMILY_APPS/2019-03-24_newest_reviews_TOP_FREE_FAMILY_apps.csv")
d_fa_0324['Category'] = 'Family'
r_fa_0324['Category'] = 'Family'
#Finance_0324
d_fin_0324 = pd.read_csv("Dataset/2019-03-24/2019-03-24_TOP_FREE_FINANCE_APPS/2019-03-24_all_detailed_TOP_FREE_FINANCE_apps.csv")
r_fin_0324 = pd.read_csv("Dataset/2019-03-24/2019-03-24_TOP_FREE_FINANCE_APPS/2019-03-24_newest_reviews_TOP_FREE_FINANCE_apps.csv")
d_fin_0324['Category'] = 'Finance'
r_fin_0324['Category'] = 'Finance'
#Game_Action_0324
d_ga_0324 = pd.read_csv("Dataset/2019-03-24/2019-03-24_TOP_FREE_GAME_ACTION_APPS/2019-03-24_all_detailed_TOP_FREE_GAME_ACTION_apps.csv")
r_ga_0324 = pd.read_csv("Dataset/2019-03-24/2019-03-24_TOP_FREE_GAME_ACTION_APPS/2019-03-24_newest_reviews_TOP_FREE_GAME_ACTION_apps.csv")
d_ga_0324['Category'] = 'Game_Action'
r_ga_0324['Category'] = 'Game_Action'
#Health_Fitness_0324
d_hf_0324 = pd.read_csv("Dataset/2019-03-24/2019-03-24_TOP_FREE_HEALTH_AND_FITNESS_APPS/2019-03-24_all_detailed_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
r_hf_0324 = pd.read_csv("Dataset/2019-03-24/2019-03-24_TOP_FREE_HEALTH_AND_FITNESS_APPS/2019-03-24_newest_reviews_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
d_hf_0324['Category'] = 'Health_Fitness'
r_hf_0324['Category'] = 'Health_Fitness'
#Lifestyle_0324
d_life_0324 = pd.read_csv("Dataset/2019-03-24/2019-03-24_TOP_FREE_LIFESTYLE_APPS/2019-03-24_all_detailed_TOP_FREE_LIFESTYLE_apps.csv")
r_life_0324 = pd.read_csv("Dataset/2019-03-24/2019-03-24_TOP_FREE_LIFESTYLE_APPS/2019-03-24_newest_reviews_TOP_FREE_LIFESTYLE_apps.csv")
d_life_0324['Category'] = 'Lifestyle'
r_life_0324['Category'] = 'Lifestyle'
#Music_Audio_0324
d_ma_0324 = pd.read_csv("Dataset/2019-03-24/2019-03-24_TOP_FREE_MUSIC_AND_AUDIO_APPS/2019-03-24_all_detailed_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
r_ma_0324 = pd.read_csv("Dataset/2019-03-24/2019-03-24_TOP_FREE_MUSIC_AND_AUDIO_APPS/2019-03-24_newest_reviews_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
d_ma_0324['Category'] = 'Music_Audio'
r_ma_0324['Category'] = 'Music_Audio'

# %% [markdown]
# ### 2019 April

# %%
#Education_0401
d_edu_0401 = pd.read_csv("Dataset/2019-04-01_TOP_FREE_categories/2019-04-01_all_detailed_TOP_FREE_EDUCATION_apps.csv")
r_edu_0401 = pd.read_csv("Dataset/2019-04-01_TOP_FREE_categories/2019-04-01_newest_reveiws_TOP_FREE_EDUCATION_apps.csv")
d_edu_0401['Category'] = 'Education'
r_edu_0401['Category'] = 'Education'
#Entertainment_0401
d_ent_0401 = pd.read_csv("Dataset/2019-04-01_TOP_FREE_categories/2019-04-01_all_detailed_TOP_FREE_ENTERTAINMENT_apps.csv")
r_ent_0401 = pd.read_csv("Dataset/2019-04-01_TOP_FREE_categories/2019-04-01_newest_reveiws_TOP_FREE_ENTERTAINMENT_apps.csv")
d_ent_0401['Category'] = 'Entertainment'
r_ent_0401['Category'] = 'Entertainment'
#Family_0401
d_fa_0401 = pd.read_csv("Dataset/2019-04-01_TOP_FREE_categories/2019-04-01_all_detailed_TOP_FREE_FAMILY_apps.csv")
r_fa_0401 = pd.read_csv("Dataset/2019-04-01_TOP_FREE_categories/2019-04-01_newest_reveiws_TOP_FREE_FAMILY_apps.csv")
d_fa_0401['Category'] = 'Family'
r_fa_0401['Category'] = 'Family'
#Finance_0401
d_fin_0401 = pd.read_csv("Dataset/2019-04-01_TOP_FREE_categories/2019-04-01_all_detailed_TOP_FREE_FINANCE_apps.csv")
r_fin_0401 = pd.read_csv("Dataset/2019-04-01_TOP_FREE_categories/2019-04-01_newest_reveiws_TOP_FREE_FINANCE_apps.csv")
d_fin_0401['Category'] = 'Finance'
r_fin_0401['Category'] = 'Finance'
#Game_Action_0401
d_ga_0401 = pd.read_csv("Dataset/2019-04-01_TOP_FREE_categories/2019-04-01_all_detailed_TOP_FREE_GAME_ACTION_apps.csv")
r_ga_0401 = pd.read_csv("Dataset/2019-04-01_TOP_FREE_categories/2019-04-01_newest_reveiws_TOP_FREE_GAME_ACTION_apps.csv")
d_ga_0401['Category'] = 'Game_Action'
r_ga_0401['Category'] = 'Game_Action'
#Health_Fitness_0401
d_hf_0401 = pd.read_csv("Dataset/2019-04-01_TOP_FREE_categories/2019-04-01_all_detailed_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
r_hf_0401 = pd.read_csv("Dataset/2019-04-01_TOP_FREE_categories/2019-04-01_newest_reveiws_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
d_hf_0401['Category'] = 'Health_Fitness'
r_hf_0401['Category'] = 'Health_Fitness'
#Lifestyle_0401
d_life_0401 = pd.read_csv("Dataset/2019-04-01_TOP_FREE_categories/2019-04-01_all_detailed_TOP_FREE_LIFESTYLE_apps.csv")
r_life_0401 = pd.read_csv("Dataset/2019-04-01_TOP_FREE_categories/2019-04-01_newest_reveiws_TOP_FREE_LIFESTYLE_apps.csv")
d_life_0401['Category'] = 'Lifestyle'
r_life_0401['Category'] = 'Lifestyle'
#Music_Audio_0401
d_ma_0401 = pd.read_csv("Dataset/2019-04-01_TOP_FREE_categories/2019-04-01_all_detailed_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
r_ma_0401 = pd.read_csv("Dataset/2019-04-01_TOP_FREE_categories/2019-04-01_newest_reveiws_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
d_ma_0401['Category'] = 'Music_Audio'
r_ma_0401['Category'] = 'Music_Audio'

#Education_0407
d_edu_0407 = pd.read_csv("Dataset/2019-04-07_TOP_FREE_category_apps/2019-04-01_all_detailed_TOP_FREE_EDUCATION_apps.csv")
r_edu_0407 = pd.read_csv("Dataset/2019-04-07_TOP_FREE_category_apps/2019-04-01_newest_reveiws_TOP_FREE_EDUCATION_apps.csv")
d_edu_0407['Category'] = 'Education'
r_edu_0407['Category'] = 'Education'
#Entertainment_0407
d_ent_0407 = pd.read_csv("Dataset/2019-04-07_TOP_FREE_category_apps/2019-04-01_all_detailed_TOP_FREE_ENTERTAINMENT_apps.csv")
r_ent_0407 = pd.read_csv("Dataset/2019-04-07_TOP_FREE_category_apps/2019-04-01_newest_reveiws_TOP_FREE_ENTERTAINMENT_apps.csv")
d_ent_0407['Category'] = 'Entertainment'
r_ent_0407['Category'] = 'Entertainment'
#Family_0407
d_fa_0407 = pd.read_csv("Dataset/2019-04-07_TOP_FREE_category_apps/2019-04-01_all_detailed_TOP_FREE_FAMILY_apps.csv")
r_fa_0407 = pd.read_csv("Dataset/2019-04-07_TOP_FREE_category_apps/2019-04-01_newest_reveiws_TOP_FREE_FAMILY_apps.csv")
d_fa_0407['Category'] = 'Family'
r_fa_0407['Category'] = 'Family'
#Finance_0407
d_fin_0407 = pd.read_csv("Dataset/2019-04-07_TOP_FREE_category_apps/2019-04-01_all_detailed_TOP_FREE_FINANCE_apps.csv")
r_fin_0407 = pd.read_csv("Dataset/2019-04-07_TOP_FREE_category_apps/2019-04-01_newest_reveiws_TOP_FREE_FINANCE_apps.csv")
d_fin_0407['Category'] = 'Finance'
r_fin_0407['Category'] = 'Finance'
#Game_Action_0407
d_ga_0407 = pd.read_csv("Dataset/2019-04-07_TOP_FREE_category_apps/2019-04-01_all_detailed_TOP_FREE_GAME_ACTION_apps.csv")
r_ga_0407 = pd.read_csv("Dataset/2019-04-07_TOP_FREE_category_apps/2019-04-01_newest_reveiws_TOP_FREE_GAME_ACTION_apps.csv")
d_ga_0407['Category'] = 'Game_Action'
r_ga_0407['Category'] = 'Game_Action'
#Health_Fitness_0407
d_hf_0407 = pd.read_csv("Dataset/2019-04-07_TOP_FREE_category_apps/2019-04-01_all_detailed_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
r_hf_0407 = pd.read_csv("Dataset/2019-04-07_TOP_FREE_category_apps/2019-04-01_newest_reveiws_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
d_hf_0407['Category'] = 'Health_Fitness'
r_hf_0407['Category'] = 'Health_Fitness'
#Lifestyle_0407
d_life_0407 = pd.read_csv("Dataset/2019-04-07_TOP_FREE_category_apps/2019-04-01_all_detailed_TOP_FREE_LIFESTYLE_apps.csv")
r_life_0407 = pd.read_csv("Dataset/2019-04-07_TOP_FREE_category_apps/2019-04-01_newest_reveiws_TOP_FREE_LIFESTYLE_apps.csv")
d_life_0407['Category'] = 'Lifestyle'
r_life_0407['Category'] = 'Lifestyle'
#Music_Audio_0407
d_ma_0407 = pd.read_csv("Dataset/2019-04-07_TOP_FREE_category_apps/2019-04-01_all_detailed_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
r_ma_0407 = pd.read_csv("Dataset/2019-04-07_TOP_FREE_category_apps/2019-04-01_newest_reveiws_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
d_ma_0407['Category'] = 'Music_Audio'
r_ma_0407['Category'] = 'Music_Audio'

#Education_0414
d_edu_0414 = pd.read_csv("Dataset/2019-04-14_TOP_FREE_category_apps/2019-04-14_all_detailed_TOP_FREE_EDUCATION_apps.csv")
r_edu_0414 = pd.read_csv("Dataset/2019-04-14_TOP_FREE_category_apps/2019-04-14_newest_reveiws_TOP_FREE_EDUCATION_apps.csv")
d_edu_0414['Category'] = 'Education'
r_edu_0414['Category'] = 'Education'
#Entertainment_0414
d_ent_0414 = pd.read_csv("Dataset/2019-04-14_TOP_FREE_category_apps/2019-04-14_all_detailed_TOP_FREE_ENTERTAINMENT_apps.csv")
r_ent_0414 = pd.read_csv("Dataset/2019-04-14_TOP_FREE_category_apps/2019-04-14_newest_reveiws_TOP_FREE_ENTERTAINMENT_apps.csv")
d_ent_0414['Category'] = 'Entertainment'
r_ent_0414['Category'] = 'Entertainment'
#Family_0414
d_fa_0414 = pd.read_csv("Dataset/2019-04-14_TOP_FREE_category_apps/2019-04-14_all_detailed_TOP_FREE_FAMILY_apps.csv")
r_fa_0414 = pd.read_csv("Dataset/2019-04-14_TOP_FREE_category_apps/2019-04-14_newest_reveiws_TOP_FREE_FAMILY_apps.csv")
d_fa_0414['Category'] = 'Family'
r_fa_0414['Category'] = 'Family'
#Finance_0414
d_fin_0414 = pd.read_csv("Dataset/2019-04-14_TOP_FREE_category_apps/2019-04-14_all_detailed_TOP_FREE_FINANCE_apps.csv")
r_fin_0414 = pd.read_csv("Dataset/2019-04-14_TOP_FREE_category_apps/2019-04-14_newest_reveiws_TOP_FREE_FINANCE_apps.csv")
d_fin_0414['Category'] = 'Finance'
r_fin_0414['Category'] = 'Finance'
#Game_Action_0414
d_ga_0414 = pd.read_csv("Dataset/2019-04-14_TOP_FREE_category_apps/2019-04-14_all_detailed_TOP_FREE_GAME_ACTION_apps.csv")
r_ga_0414 = pd.read_csv("Dataset/2019-04-14_TOP_FREE_category_apps/2019-04-14_newest_reveiws_TOP_FREE_GAME_ACTION_apps.csv")
d_ga_0414['Category'] = 'Game_Action'
r_ga_0414['Category'] = 'Game_Action'
#Health_Fitness_0414
d_hf_0414 = pd.read_csv("Dataset/2019-04-14_TOP_FREE_category_apps/2019-04-14_all_detailed_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
r_hf_0414 = pd.read_csv("Dataset/2019-04-14_TOP_FREE_category_apps/2019-04-14_newest_reveiws_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
d_hf_0414['Category'] = 'Health_Fitness'
r_hf_0414['Category'] = 'Health_Fitness'
#Lifestyle_0414
d_life_0414 = pd.read_csv("Dataset/2019-04-14_TOP_FREE_category_apps/2019-04-14_all_detailed_TOP_FREE_LIFESTYLE_apps.csv")
r_life_0414 = pd.read_csv("Dataset/2019-04-14_TOP_FREE_category_apps/2019-04-14_newest_reveiws_TOP_FREE_LIFESTYLE_apps.csv")
d_life_0414['Category'] = 'Lifestyle'
r_life_0414['Category'] = 'Lifestyle'
#Music_Audio_0414
d_ma_0414 = pd.read_csv("Dataset/2019-04-14_TOP_FREE_category_apps/2019-04-14_all_detailed_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
r_ma_0414 = pd.read_csv("Dataset/2019-04-14_TOP_FREE_category_apps/2019-04-14_newest_reveiws_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
d_ma_0414['Category'] = 'Music_Audio'
r_ma_0414['Category'] = 'Music_Audio'

#Education_0421
d_edu_0421 = pd.read_csv("Dataset/2019-04-21_TOP_FREE_category_apps/2019-04-21_all_detailed_TOP_FREE_EDUCATION_apps.csv")
r_edu_0421 = pd.read_csv("Dataset/2019-04-21_TOP_FREE_category_apps/2019-04-21_newest_reveiws_TOP_FREE_EDUCATION_apps.csv")
d_edu_0421['Category'] = 'Education'
r_edu_0421['Category'] = 'Education'
#Entertainment_0421
d_ent_0421 = pd.read_csv("Dataset/2019-04-21_TOP_FREE_category_apps/2019-04-21_all_detailed_TOP_FREE_ENTERTAINMENT_apps.csv")
r_ent_0421 = pd.read_csv("Dataset/2019-04-21_TOP_FREE_category_apps/2019-04-21_newest_reveiws_TOP_FREE_ENTERTAINMENT_apps.csv")
d_ent_0421['Category'] = 'Entertainment'
r_ent_0421['Category'] = 'Entertainment'
#Family_0421
d_fa_0421 = pd.read_csv("Dataset/2019-04-21_TOP_FREE_category_apps/2019-04-21_all_detailed_TOP_FREE_FAMILY_apps.csv")
r_fa_0421 = pd.read_csv("Dataset/2019-04-21_TOP_FREE_category_apps/2019-04-21_newest_reveiws_TOP_FREE_FAMILY_apps.csv")
d_fa_0421['Category'] = 'Family'
r_fa_0421['Category'] = 'Family'
#Finance_0421
d_fin_0421 = pd.read_csv("Dataset/2019-04-21_TOP_FREE_category_apps/2019-04-21_all_detailed_TOP_FREE_FINANCE_apps.csv")
r_fin_0421 = pd.read_csv("Dataset/2019-04-21_TOP_FREE_category_apps/2019-04-21_newest_reveiws_TOP_FREE_FINANCE_apps.csv")
d_fin_0421['Category'] = 'Finance'
r_fin_0421['Category'] = 'Finance'
#Game_Action_0421
d_ga_0421 = pd.read_csv("Dataset/2019-04-21_TOP_FREE_category_apps/2019-04-21_all_detailed_TOP_FREE_GAME_ACTION_apps.csv")
r_ga_0421 = pd.read_csv("Dataset/2019-04-21_TOP_FREE_category_apps/2019-04-21_newest_reveiws_TOP_FREE_GAME_ACTION_apps.csv")
d_ga_0421['Category'] = 'Game_Action'
r_ga_0421['Category'] = 'Game_Action'
#Health_Fitness_0421
d_hf_0421 = pd.read_csv("Dataset/2019-04-21_TOP_FREE_category_apps/2019-04-21_all_detailed_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
r_hf_0421 = pd.read_csv("Dataset/2019-04-21_TOP_FREE_category_apps/2019-04-21_newest_reveiws_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
d_hf_0421['Category'] = 'Health_Fitness'
r_hf_0421['Category'] = 'Health_Fitness'
#Lifestyle_0421
d_life_0421 = pd.read_csv("Dataset/2019-04-21_TOP_FREE_category_apps/2019-04-21_all_detailed_TOP_FREE_LIFESTYLE_apps.csv")
r_life_0421 = pd.read_csv("Dataset/2019-04-21_TOP_FREE_category_apps/2019-04-21_newest_reveiws_TOP_FREE_LIFESTYLE_apps.csv")
d_life_0421['Category'] = 'Lifestyle'
r_life_0421['Category'] = 'Lifestyle'
#Music_Audio_0421
d_ma_0421 = pd.read_csv("Dataset/2019-04-21_TOP_FREE_category_apps/2019-04-21_all_detailed_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
r_ma_0421 = pd.read_csv("Dataset/2019-04-21_TOP_FREE_category_apps/2019-04-21_newest_reveiws_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
d_ma_0421['Category'] = 'Music_Audio'
r_ma_0421['Category'] = 'Music_Audio'

# %% [markdown]
# ### 2019 May

# %%
#Education_0501
d_edu_0501 = pd.read_csv("Dataset/2019-05-01_TOP_FREE_category_apps/2019-05-01_all_detailed_TOP_FREE_EDUCATION_apps.csv")
r_edu_0501 = pd.read_csv("Dataset/2019-05-01_TOP_FREE_category_apps/2019-05-01_newest_reveiws_TOP_FREE_EDUCATION_apps.csv")
d_edu_0501['Category'] = 'Education'
r_edu_0501['Category'] = 'Education'
#Entertainment_0501
d_ent_0501 = pd.read_csv("Dataset/2019-05-01_TOP_FREE_category_apps/2019-05-01_all_detailed_TOP_FREE_ENTERTAINMENT_apps.csv")
r_ent_0501 = pd.read_csv("Dataset/2019-05-01_TOP_FREE_category_apps/2019-05-01_newest_reveiws_TOP_FREE_ENTERTAINMENT_apps.csv")
d_ent_0501['Category'] = 'Entertainment'
r_ent_0501['Category'] = 'Entertainment'
#Family_0501
d_fa_0501 = pd.read_csv("Dataset/2019-05-01_TOP_FREE_category_apps/2019-05-01_all_detailed_TOP_FREE_FAMILY_apps.csv")
r_fa_0501 = pd.read_csv("Dataset/2019-05-01_TOP_FREE_category_apps/2019-05-01_newest_reveiws_TOP_FREE_FAMILY_apps.csv")
d_fa_0501['Category'] = 'Family'
r_fa_0501['Category'] = 'Family'
#Finance_0501
d_fin_0501 = pd.read_csv("Dataset/2019-05-01_TOP_FREE_category_apps/2019-05-01_all_detailed_TOP_FREE_FINANCE_apps.csv")
r_fin_0501 = pd.read_csv("Dataset/2019-05-01_TOP_FREE_category_apps/2019-05-01_newest_reveiws_TOP_FREE_FINANCE_apps.csv")
d_fin_0501['Category'] = 'Finance'
r_fin_0501['Category'] = 'Finance'
#Game_Action_0501
d_ga_0501 = pd.read_csv("Dataset/2019-05-01_TOP_FREE_category_apps/2019-05-01_all_detailed_TOP_FREE_GAME_ACTION_apps.csv")
r_ga_0501 = pd.read_csv("Dataset/2019-05-01_TOP_FREE_category_apps/2019-05-01_newest_reveiws_TOP_FREE_GAME_ACTION_apps.csv")
d_ga_0501['Category'] = 'Game_Action'
r_ga_0501['Category'] = 'Game_Action'
#Health_Fitness_0501
d_hf_0501 = pd.read_csv("Dataset/2019-05-01_TOP_FREE_category_apps/2019-05-01_all_detailed_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
r_hf_0501 = pd.read_csv("Dataset/2019-05-01_TOP_FREE_category_apps/2019-05-01_newest_reveiws_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
d_hf_0501['Category'] = 'Health_Fitness'
r_hf_0501['Category'] = 'Health_Fitness'
#Lifestyle_0501
d_life_0501 = pd.read_csv("Dataset/2019-05-01_TOP_FREE_category_apps/2019-05-01_all_detailed_TOP_FREE_LIFESTYLE_apps.csv")
r_life_0501 = pd.read_csv("Dataset/2019-05-01_TOP_FREE_category_apps/2019-05-01_newest_reveiws_TOP_FREE_LIFESTYLE_apps.csv")
d_life_0501['Category'] = 'Lifestyle'
r_life_0501['Category'] = 'Lifestyle'
#Music_Audio_0501
d_ma_0501 = pd.read_csv("Dataset/2019-05-01_TOP_FREE_category_apps/2019-05-01_all_detailed_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
r_ma_0501 = pd.read_csv("Dataset/2019-05-01_TOP_FREE_category_apps/2019-05-01_newest_reveiws_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
d_ma_0501['Category'] = 'Music_Audio'
r_ma_0501['Category'] = 'Music_Audio'

#Education_0509
d_edu_0509 = pd.read_csv("Dataset/2019-05-09_TOP_FREE_category_apps/2019-05-09_all_detailed_TOP_FREE_EDUCATION_apps.csv")
r_edu_0509 = pd.read_csv("Dataset/2019-05-09_TOP_FREE_category_apps/2019-05-09_newest_reveiws_TOP_FREE_EDUCATION_apps.csv")
d_edu_0509['Category'] = 'Education'
r_edu_0509['Category'] = 'Education'
#Entertainment_0509
d_ent_0509 = pd.read_csv("Dataset/2019-05-09_TOP_FREE_category_apps/2019-05-09_all_detailed_TOP_FREE_ENTERTAINMENT_apps.csv")
r_ent_0509 = pd.read_csv("Dataset/2019-05-09_TOP_FREE_category_apps/2019-05-09_newest_reveiws_TOP_FREE_ENTERTAINMENT_apps.csv")
d_ent_0509['Category'] = 'Entertainment'
r_ent_0509['Category'] = 'Entertainment'
#Family_0509
d_fa_0509 = pd.read_csv("Dataset/2019-05-09_TOP_FREE_category_apps/2019-05-09_all_detailed_TOP_FREE_FAMILY_apps.csv")
r_fa_0509 = pd.read_csv("Dataset/2019-05-09_TOP_FREE_category_apps/2019-05-09_newest_reveiws_TOP_FREE_FAMILY_apps.csv")
d_fa_0509['Category'] = 'Family'
r_fa_0509['Category'] = 'Family'
#Finance_0509
d_fin_0509 = pd.read_csv("Dataset/2019-05-09_TOP_FREE_category_apps/2019-05-09_all_detailed_TOP_FREE_FINANCE_apps.csv")
r_fin_0509 = pd.read_csv("Dataset/2019-05-09_TOP_FREE_category_apps/2019-05-09_newest_reveiws_TOP_FREE_FINANCE_apps.csv")
d_fin_0509['Category'] = 'Finance'
r_fin_0509['Category'] = 'Finance'
#Game_Action_0509
d_ga_0509 = pd.read_csv("Dataset/2019-05-09_TOP_FREE_category_apps/2019-05-09_all_detailed_TOP_FREE_GAME_ACTION_apps.csv")
r_ga_0509 = pd.read_csv("Dataset/2019-05-09_TOP_FREE_category_apps/2019-05-09_newest_reveiws_TOP_FREE_GAME_ACTION_apps.csv")
d_ga_0509['Category'] = 'Game_Action'
r_ga_0509['Category'] = 'Game_Action'
#Health_Fitness_0509
d_hf_0509 = pd.read_csv("Dataset/2019-05-09_TOP_FREE_category_apps/2019-05-09_all_detailed_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
r_hf_0509 = pd.read_csv("Dataset/2019-05-09_TOP_FREE_category_apps/2019-05-09_newest_reveiws_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
d_hf_0509['Category'] = 'Health_Fitness'
r_hf_0509['Category'] = 'Health_Fitness'
#Lifestyle_0509
d_life_0509 = pd.read_csv("Dataset/2019-05-09_TOP_FREE_category_apps/2019-05-09_all_detailed_TOP_FREE_LIFESTYLE_apps.csv")
r_life_0509 = pd.read_csv("Dataset/2019-05-09_TOP_FREE_category_apps/2019-05-09_newest_reveiws_TOP_FREE_LIFESTYLE_apps.csv")
d_life_0509['Category'] = 'Lifestyle'
r_life_0509['Category'] = 'Lifestyle'
#Music_Audio_0509
d_ma_0509 = pd.read_csv("Dataset/2019-05-09_TOP_FREE_category_apps/2019-05-09_all_detailed_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
r_ma_0509 = pd.read_csv("Dataset/2019-05-09_TOP_FREE_category_apps/2019-05-09_newest_reveiws_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
d_ma_0509['Category'] = 'Music_Audio'
r_ma_0509['Category'] = 'Music_Audio'

# %%
dflist = [r_edu_0308, r_fin_0308, r_ga_0308, r_ma_0309, r_ent_0313, r_fa_0313, r_life_0313, r_hf_0316, r_edu_0324, 
          r_ent_0324, r_fa_0324, r_fin_0324, r_ga_0324, r_hf_0324, r_life_0324, r_ma_0324, r_edu_0401, r_ent_0401,
          r_fa_0401, r_fin_0401, r_ga_0401, r_hf_0401, r_life_0401, r_ma_0401, r_edu_0407, r_ent_0407,
          r_fa_0407, r_fin_0407, r_ga_0407, r_hf_0407, r_life_0407, r_ma_0407, r_edu_0414, r_ent_0414,
          r_fa_0414, r_fin_0414, r_ga_0414, r_hf_0414, r_life_0414, r_ma_0414, r_edu_0421, r_ent_0421,
          r_fa_0421, r_fin_0421, r_ga_0421, r_hf_0421, r_life_0421, r_ma_0421, r_edu_0501, r_ent_0501,
          r_fa_0501, r_fin_0501, r_ga_0501, r_hf_0501, r_life_0501, r_ma_0501, r_edu_0509, r_ent_0509,
          r_fa_0509, r_fin_0509, r_ga_0509, r_hf_0509, r_life_0509, r_ma_0509]
df_review = pd.concat(dflist, ignore_index=True)

# %%
df_review.shape
# Out:
# (2715303, 6)

# %%
df_review.head()
# Out:
#     appTitle userName           date  score  \
# 0  Photomath      NaN  March 8, 2019      5
# 1  Photomath      NaN  March 8, 2019      4
# 2  Photomath      NaN  March 8, 2019      5
# 3  Photomath      NaN  March 8, 2019      5
# 4  Photomath      NaN  March 8, 2019      1
#
#                                                 text   Category
# 0                                               nice  Education
# 1                                       very helpful  Education
# 2  Great App. Detailed answers. Understandable an...  Education
# 3                                           great!!!  Education
# 4                  bakwas hai pura.....time pass hai  Education

# %%
import missingno as msno

# %%
#lots of missing values in appTitle column 
msno.matrix(df_review)

# %%
dropped_appTitle=pd.Series(df_review.dropna().appTitle.unique()).to_dict()
for t in range(0,len(dropped_appTitle)):
    df_review.loc[(df_review.appTitle.isnull()) & 
                  (df_review['text'].str.contains(dropped_appTitle[t])==True),'appTitle']=dropped_appTitle[t]
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   after removing the cwd from sys.path.

# %%
#looks like some of NaN are replaced in appTitle colummn 
msno.matrix(df_review)

# %%
#Counting missing values in review dataframe
missing_data = df_review.isnull()
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# appTitle
# False    2377086
# True      338217
# Name: appTitle, dtype: int64
#
# userName
# False    2491296
# True      224007
# Name: userName, dtype: int64
#
# date
# False    2715303
# Name: date, dtype: int64
#
# score
# False    2715303
# Name: score, dtype: int64
#
# text
# False    2715121
# True         182
# Name: text, dtype: int64
#
# Category
# False    2715303
# Name: Category, dtype: int64

# %%
#drop NaN in 'text' and 'appTitle' column
df_review = df_review.dropna(subset=['appTitle', 'text'])

# %%
msno.matrix(df_review)

# %%
df_review.shape
# Out:
# (2376926, 6)

# %%
dflist2 = [d_edu_0308, d_fin_0308, d_ga_0308, d_ma_0309, d_ent_0313, d_fa_0313, d_life_0313, d_hf_0316, d_edu_0324, 
          d_ent_0324, d_fa_0324, d_fin_0324, d_ga_0324, d_hf_0324, d_life_0324, d_ma_0324, d_edu_0401, d_ent_0401,
          d_fa_0401, d_fin_0401, d_ga_0401, d_hf_0401, d_life_0401, d_ma_0401, d_edu_0407, d_ent_0407,
          d_fa_0407, d_fin_0407, d_ga_0407, d_hf_0407, d_life_0407, d_ma_0407, d_edu_0414, d_ent_0414,
          d_fa_0414, d_fin_0414, d_ga_0414, d_hf_0414, d_life_0414, d_ma_0414, d_edu_0421, d_ent_0421,
          d_fa_0421, d_fin_0421, d_ga_0421, d_hf_0421, d_life_0421, d_ma_0421, d_edu_0501, d_ent_0501,
          d_fa_0501, d_fin_0501, d_ga_0501, d_hf_0501, d_life_0501, d_ma_0501, d_edu_0509, d_ent_0509,
          d_fa_0509, d_fin_0509, d_ga_0509, d_hf_0509, d_life_0509, d_ma_0509]
df_detailed = pd.concat(dflist2, ignore_index=True)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if __name__ == '__main__':

# %%
df_detailed.shape
# Out:
# (637, 59)

# %% [markdown]
# ### Initial Statistics

# %% [markdown]
# #### 1. Drop duplicates and record how many unique reviews are collected?

# %%
df_detailed = df_detailed.drop_duplicates()

# %%
len(df_detailed.index)
# Out:
# 637

# %%
df_review = df_review.drop_duplicates()

# %%
len(df_review.index)
# Out:
# 1142769

# %% [markdown]
# #### 2. How many unique apps are in the dataset? How many apps in each of the 8 specified app categories?

# %%
df_review.appTitle.nunique()
# Out:
# 87

# %%
df_review.groupby('Category')['appTitle'].nunique()
# Out:
# Category
# Education         15
# Entertainment     17
# Family            15
# Finance           13
# Game_Action       13
# Health_Fitness    12
# Lifestyle         17
# Music_Audio       16
# Name: appTitle, dtype: int64

# %% [markdown]
# #### 3. How many reviews exist in each of the eight app-categories?

# %%
df_review.groupby('Category')['text'].size()
# Out:
# Category
# Education          95936
# Entertainment     184300
# Family            125543
# Finance           141238
# Game_Action       209535
# Health_Fitness    110035
# Lifestyle         103097
# Music_Audio       173085
# Name: text, dtype: int64

# %% [markdown]
# #### 4. Based on the contentRating column in the details files for each app, what are the different contentRating groups in each app-category?

# %%
df_detailed.groupby('Category')['contentRating'].unique()
# Out:
# Category
# Education                           [Everyone, nan]
# Entertainment     [Teen, Everyone, Mature 17+, nan]
# Family                [Everyone 10+, Everyone, nan]
# Finance                             [Everyone, nan]
# Game_Action       [Everyone, Teen, Mature 17+, nan]
# Health_Fitness                      [Everyone, nan]
# Lifestyle         [Everyone, Mature 17+, Teen, nan]
# Music_Audio                   [Teen, Everyone, nan]
# Name: contentRating, dtype: object

# %% [markdown]
# #### 5. How many apps exist in each of these contentRating-sub-groups in each app-category?

# %%
df_detailed.groupby(['Category','contentRating'])[['appId']].size()
# Out:
# Category        contentRating
# Education       Everyone         60
# Entertainment   Everyone          6
#                 Mature 17+        6
#                 Teen             48
# Family          Everyone         42
#                 Everyone 10+     18
# Finance         Everyone         60
# Game_Action     Everyone         30
#                 Mature 17+        6
#                 Teen             24
# Health_Fitness  Everyone         60
# Lifestyle       Everyone         52
#                 Mature 17+        6
#                 Teen              1
# Music_Audio     Everyone         12
#                 Teen             48
# dtype: int64

# %% [markdown]
# #### 6. How many reviews in each contentRating-sub-groups in each app-category?

# %%
df_detailed.groupby(['Category','contentRating'])[['reviews']].sum()
# Out:
#                                  reviews
# Category       contentRating
# Education      Everyone       21187631.0
# Entertainment  Everyone        1254289.0
#                Mature 17+       213348.0
#                Teen           34625967.0
# Family         Everyone       21952032.0
#                Everyone 10+   44649433.0
# Finance        Everyone        8368128.0
# Game_Action    Everyone       24876647.0
#                Mature 17+     19033933.0
#                Teen           49456760.0
# Health_Fitness Everyone        8997622.0
# Lifestyle      Everyone        4202447.0
#                Mature 17+      5091935.0
#                Teen               8880.0
# Music_Audio    Everyone         836336.0
#                Teen           45152540.0

# %% [markdown]
# ### Text Pre-processing

# %% [markdown]
# Apply the following on the text column.
# - Remove the non-English reviews.
# - Remove the non-ASCII characters.
# - Remove punctuations.
# - Remove multiple characters if they occur more than 2 times continuously. Check your results so
# that it does not change words such as HELLO that has 2 Ls.

# %%
df_review.head()
# Out:
#     appTitle userName           date  score  \
# 0  Photomath      NaN  March 8, 2019      5
# 1  Photomath      NaN  March 8, 2019      4
# 2  Photomath      NaN  March 8, 2019      5
# 3  Photomath      NaN  March 8, 2019      5
# 4  Photomath      NaN  March 8, 2019      1
#
#                                                 text   Category
# 0                                               nice  Education
# 1                                       very helpful  Education
# 2  Great App. Detailed answers. Understandable an...  Education
# 3                                           great!!!  Education
# 4                  bakwas hai pura.....time pass hai  Education

# %%
df_review['text'] = df_review['text'].astype(str)

# %%
import nltk 
nltk.download('stopwords')
nltk.download('words')
import string
import re
from collections import Counter
import enchant
import langid
import numpy as np
import itertools
from collections import OrderedDict
# Out:
# [nltk_data] Downloading package stopwords to /Users/jay/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to /Users/jay/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
df_review.shape
# Out:
# (1142769, 6)

# %%
def remove_nonEnglish(x):
    return langid.classify(x)[0] !='en'

# %%
index_nonEng=df_review[df_review['text'].map(remove_nonEnglish) == True].index.tolist()

# %%
df_review1 = df_review.drop(index_nonEng)

# %%
df_review1.shape
# Out:
# (1011357, 6)

# %%
#Remove punctuations
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

df_review1["text_RemovePunct"] = df_review1["text"].apply(lambda text: remove_punctuation(text))

# %%
df_review1.head()
# Out:
#     appTitle         userName           date  score  \
# 0  Photomath              NaN  March 8, 2019      5
# 1  Photomath              NaN  March 8, 2019      4
# 2  Photomath              NaN  March 8, 2019      5
# 3  Photomath              NaN  March 8, 2019      5
# 6  Photomath  אוביידו אדריאנה  March 8, 2019      5
#
#                                                 text   Category  \
# 0                                               nice  Education
# 1                                       very helpful  Education
# 2  Great App. Detailed answers. Understandable an...  Education
# 3                                           great!!!  Education
# 6           Great tool for learning math, I love it!  Education
#
#                                     text_RemovePunct
# 0                                               nice
# 1                                       very helpful
# 2  Great App Detailed answers Understandable answers
# ...

# %%
#Remove the non-ASCII characters.
def remove_non_ascii(text):
    return ''.join(i for i in text if ord(i)<128)
 
df_review1['text_RemoveNonAscii'] = df_review1['text'].apply(remove_non_ascii)

# %%
df_review1.head()
# Out:
#     appTitle         userName           date  score  \
# 0  Photomath              NaN  March 8, 2019      5
# 1  Photomath              NaN  March 8, 2019      4
# 2  Photomath              NaN  March 8, 2019      5
# 3  Photomath              NaN  March 8, 2019      5
# 6  Photomath  אוביידו אדריאנה  March 8, 2019      5
#
#                                                 text   Category  \
# 0                                               nice  Education
# 1                                       very helpful  Education
# 2  Great App. Detailed answers. Understandable an...  Education
# 3                                           great!!!  Education
# 6           Great tool for learning math, I love it!  Education
#
#                                     text_RemovePunct  \
# 0                                               nice
# 1                                       very helpful
# 2  Great App Detailed answers Understandable answers
# ...

# %%
#Remove multiple character
def replaceRepeat(x):
    return re.sub(r'([a-z])\1{2,}', r'\1\1', x)
df_review1['text_removeMultiChar']= df_review1['text'].map(replaceRepeat)

# %%
df_review1.head()
# Out:
#     appTitle         userName           date  score  \
# 0  Photomath              NaN  March 8, 2019      5
# 1  Photomath              NaN  March 8, 2019      4
# 2  Photomath              NaN  March 8, 2019      5
# 3  Photomath              NaN  March 8, 2019      5
# 6  Photomath  אוביידו אדריאנה  March 8, 2019      5
#
#                                                 text   Category  \
# 0                                               nice  Education
# 1                                       very helpful  Education
# 2  Great App. Detailed answers. Understandable an...  Education
# 3                                           great!!!  Education
# 6           Great tool for learning math, I love it!  Education
#
#                                     text_RemovePunct  \
# 0                                               nice
# 1                                       very helpful
# 2  Great App Detailed answers Understandable answers
# ...

# %%
#df_review1.to_csv('df_review_text_processed_columns_added.csv')

# %%
df_review1 = df_review1.drop('text_RemoveNonAscii', axis = 1)

# %%
df_review1 = df_review1.drop('text_RemovePunct', axis = 1)

# %%
df_review1 = df_review1.drop('text_removeMultiChar', axis = 1)

# %%
#Remove the non-ASCII characters.
def remove_non_ascii(text):
    return ''.join(i for i in text if ord(i)<128)
 
df_review1['text'] = df_review1['text'].apply(remove_non_ascii)

# %%
#Remove punctuations
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

df_review1['text'] = df_review1["text"].apply(lambda text: remove_punctuation(text))

# %%
#Remove multiple character
def remove_multiChar(x):
    return re.sub(r'([a-z])\1{2,}', r'\1\1', x)
df_review['text']= df_review['text'].map(remove_multiChar)

# %%
df_review1.head()
# Out:
#     appTitle         userName           date  score  \
# 0  Photomath              NaN  March 8, 2019      5
# 1  Photomath              NaN  March 8, 2019      4
# 2  Photomath              NaN  March 8, 2019      5
# 3  Photomath              NaN  March 8, 2019      5
# 6  Photomath  אוביידו אדריאנה  March 8, 2019      5
#
#                                                 text   Category
# 0                                               nice  Education
# 1                                       very helpful  Education
# 2  Great App Detailed answers Understandable answers  Education
# 3                                              great  Education
# 6             Great tool for learning math I love it  Education

# %%
df_review1.shape
# Out:
# (1011357, 6)

# %% [markdown]
# #### 7. Should we remove the reviews that contain two or less number of words?

# %%
#Remove the reviews that have two or less number of words.
lessWords_index = df_review1[df_review1.text.str.count('') <= 2].index.tolist()
df_review1 = df_review1.drop(lessWords_index)

# %%
df_review1.shape
# Out:
# (1009798, 6)

# %% [markdown]
# #### 8. How many reviews exist in each of the eight app-categories? Compare with question 3.

# %%
from IPython.display import Image

# %%
#Q3
Image(filename='data542_project_Q3.png')

# %%
df_review1.groupby('Category')['text'].size()
# Out:
# Category
# Education          85446
# Entertainment     161045
# Family            109108
# Finance           128905
# Game_Action       176923
# Health_Fitness    101306
# Lifestyle          93027
# Music_Audio       154038
# Name: text, dtype: int64

# %% [markdown]
# #### 9. How many reviews in each contentRating-sub-groups in each app-category? Compare with question 6.

# %%
detailed_appTitle = df_detailed.drop_duplicates(subset = 'appTitle', keep = 'first')[['appTitle','contentRating']]

# %%
df_review1['contentRating'] = df_review1['appTitle'].map(detailed_appTitle.set_index('appTitle')['contentRating'])

# %%
df_review1.groupby(['Category','contentRating'])['text'].size()
# Out:
# Category        contentRating
# Education       Everyone          85430
#                 Everyone 10+          2
#                 Teen                 14
# Entertainment   Everyone          12524
#                 Mature 17+         6567
#                 Teen             141954
# Family          Everyone          66434
#                 Everyone 10+      42659
#                 Teen                 15
# Finance         Everyone         128901
#                 Everyone 10+          1
#                 Mature 17+            2
#                 Teen                  1
# Game_Action     Everyone          74502
#                 Everyone 10+          6
#                 Mature 17+        24722
#                 Teen              77693
# Health_Fitness  Everyone         101291
#                 Everyone 10+          1
#                 Teen                 14
# Lifestyle       Everyone          70886
#                 Mature 17+        19614
#                 Teen               2527
# ...

# %%
#df_review1.to_csv('df_review_text_processed.csv')

# %% [markdown]
# ### Analyzing Each Category.

# %% [markdown]
# #### 10. What is the number of reviews for each score (score column)? For example, 35000 reviews have a score of 1, etc.

# %%
df_review1 = pd.read_csv("df_review_text_processed.csv")
df_review1.groupby(['score','Category'])['text'].size()
# Out:
# score  Category
# 1      Education           6859
#        Entertainment      17852
#        Family             10262
#        Finance            19032
#        Game_Action        18765
#        Health_Fitness     14362
#        Lifestyle          26350
#        Music_Audio        26342
# 2      Education           1733
#        Entertainment       5289
#        Family              2694
#        Finance             3619
#        Game_Action         4149
#        Health_Fitness      4577
#        Lifestyle           3867
#        Music_Audio         7931
# 3      Education           3588
#        Entertainment       9005
#        Family              5246
#        Finance             4299
#        Game_Action         8457
#        Health_Fitness      5720
#        Lifestyle           5053
#        Music_Audio        10140
# 4      Education           9086
#        Entertainment      19359
#        Family             11753
#        Finance            11419
# ...

# %% [markdown]
# #### 11. How many apps exist in each score-sub-group?

# %%
df_review1.groupby(['score','Category'])['appTitle'].nunique()
# Out:
# score  Category
# 1      Education         12
#        Entertainment     16
#        Family            12
#        Finance           12
#        Game_Action       13
#        Health_Fitness    11
#        Lifestyle         15
#        Music_Audio       14
# 2      Education         10
#        Entertainment     14
#        Family            11
#        Finance           10
#        Game_Action       13
#        Health_Fitness    11
#        Lifestyle         16
#        Music_Audio       14
# 3      Education         12
#        Entertainment     16
#        Family            14
#        Finance           10
#        Game_Action       11
#        Health_Fitness    11
#        Lifestyle         14
#        Music_Audio       16
# 4      Education         13
#        Entertainment     14
#        Family            11
#        Finance           10
#        Game_Action       11
#        Health_Fitness    11
#        Lifestyle         15
#        Music_Audio       13
# ...

# %% [markdown]
# #### 12. Compare the number of reviews for each score in a plot (Remember to normalize the numbers when you are comparing them).

# %%
import matplotlib.pyplot as plt

# %%
df_review1.groupby(['score'])['text'].size().plot(kind='bar')
plt.show()

# %% [markdown]
# #### 13. What is the average length of the reviews in each score-sub-group?

# %%
df_review1['review_length']=df_review1['text'].str.len()

# %%
df_review1.head()
# Out:
#    Unnamed: 0   appTitle         userName           date  score  \
# 0           0  Photomath              NaN  March 8, 2019      5
# 1           1  Photomath              NaN  March 8, 2019      4
# 2           2  Photomath              NaN  March 8, 2019      5
# 3           3  Photomath              NaN  March 8, 2019      5
# 4           6  Photomath  אוביידו אדריאנה  March 8, 2019      5
#
#                                                 text   Category contentRating  \
# 0                                               nice  Education      Everyone
# 1                                       very helpful  Education      Everyone
# 2  Great App Detailed answers Understandable answers  Education      Everyone
# 3                                              great  Education      Everyone
# 4             Great tool for learning math I love it  Education      Everyone
#
#    review_length
# 0              4
# 1             12
# 2             49
# 3              5
# 4             38

# %%
df_review1.groupby(['score'])['review_length'].mean()
# Out:
# score
# 1    110.457153
# 2    133.616025
# 3     99.865380
# 4     68.111887
# 5     39.953418
# Name: review_length, dtype: float64

# %% [markdown]
# #### 14. Compare the average length of reviews in each score-sub-group in the 8 app categories (draw a plot).

# %%
df_review1.groupby(['score', 'Category'])['review_length'].mean().unstack().plot(kind='bar')
plt.legend(loc = "center left", bbox_to_anchor = (1.0, 0.5))

# %% [markdown]
# #### 15. Compare the number of reviews in each score-sub-group in the 8 app categories (draw a plot).

# %%
df_review1.groupby(['score', 'Category'])['text'].count().unstack().plot(kind='bar')
plt.legend(loc = "center left", bbox_to_anchor = (1.0, 0.5))

# %% [markdown]
# #### 16. Compare the number of apps in each score-sub-group in the 8 app categories (draw a plot).

# %%
df_review1.groupby(['score','Category'])['appTitle'].nunique().unstack().plot(kind='bar')
plt.legend(loc = "center left", bbox_to_anchor = (1.0, 0.5))

# %% [markdown]
# ### Correlation Analysis.

# %% [markdown]
# #### 17. Is there any correlation between the length of the reviews and the score in each app-category?

# %%
df_review1.groupby('Category')[['score', 'review_length']].corr().iloc[0::2, -1]
# Out:
# Category
# Education       score   -0.220047
# Entertainment   score   -0.315343
# Family          score   -0.182052
# Finance         score   -0.462150
# Game_Action     score   -0.234174
# Health_Fitness  score   -0.344822
# Lifestyle       score   -0.366226
# Music_Audio     score   -0.404150
# Name: review_length, dtype: float64

# %%
import seaborn as sn
corrMatrix = df_review1.corr()
sn.heatmap(corrMatrix, annot=True)

# %% [markdown]
# ### Date-time Analysis.

# %% [markdown]
# #### 18. Find the evolution/changes of the star rating and length of reviews during time for each app category. Draw plots.

# %% [markdown]
# - a. Can we use the date column for this question?
# - b. If not, what is the solution based on the data you have?

# %%
import datetime
df_review1['date'] = pd.to_datetime(df_review1['date'])

# %%
df_review1['date'] = df_review1['date'].mask(df_review1['date'].dt.year == 2014, df_review1['date'] + pd.offsets.DateOffset(year=2019))
df_review1['date'] = df_review1['date'].mask(df_review1['date'].dt.year == 2015, df_review1['date'] + pd.offsets.DateOffset(year=2019))
df_review1['date'] = df_review1['date'].mask(df_review1['date'].dt.year == 2016, df_review1['date'] + pd.offsets.DateOffset(year=2019))
df_review1['date'] = df_review1['date'].mask(df_review1['date'].dt.year == 2017, df_review1['date'] + pd.offsets.DateOffset(year=2019))
df_review1['date'] = df_review1['date'].mask(df_review1['date'].dt.year == 2018, df_review1['date'] + pd.offsets.DateOffset(year=2019))
# Out:
# //anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py:743: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex
#   "or DatetimeIndex", PerformanceWarning)

# %%
df_review1['date_month'] = pd.DatetimeIndex(df_review1['date']).month

# %%
df_review1.head()
# Out:
#    Unnamed: 0   appTitle         userName       date  score  \
# 0           0  Photomath              NaN 2019-03-08      5
# 1           1  Photomath              NaN 2019-03-08      4
# 2           2  Photomath              NaN 2019-03-08      5
# 3           3  Photomath              NaN 2019-03-08      5
# 4           6  Photomath  אוביידו אדריאנה 2019-03-08      5
#
#                                                 text   Category contentRating  \
# 0                                               nice  Education      Everyone
# 1                                       very helpful  Education      Everyone
# 2  Great App Detailed answers Understandable answers  Education      Everyone
# 3                                              great  Education      Everyone
# 4             Great tool for learning math I love it  Education      Everyone
#
#    review_length  date_month
# 0              4           3
# 1             12           3
# 2             49           3
# ...

# %%
import calendar
df_review1['date_month'] = df_review1['date_month'].apply(lambda x: calendar.month_abbr[x])

# %%
import numpy as np
pd.DataFrame(df_review1.groupby(['date_month', 'Category'])['text'].apply(lambda x: np.mean(x.str.len()))).unstack().plot.bar(stacked=True,figsize=(10,7))
plt.xlabel('Month')
plt.ylabel('Average Lenngth Review')
plt.legend(loc = 'center left', bbox_to_anchor = (1.0, 0.5))
plt.show()

# %% [markdown]
# ### Manual Evaluation

# %%
df1 = df_review1[df_review1.score == 1].sample(5)
df2 = df_review1[df_review1.score == 2].sample(5)
df3 = df_review1[df_review1.score == 3].sample(5)
df4 = df_review1[df_review1.score == 4].sample(5)
df5 = df_review1[df_review1.score == 5].sample(5)

# %%
df_manual = pd.concat([df1, df2, df3, df4, df5])

# %%
df_manual
# Out:
#         Unnamed: 0                                          appTitle  \
# 703929     1426469                                Amazon Prime Video
# 518595      862450                                    Kick the Buddy
# 842348     1934106                                            Fitbit
# 444620      722844                                             STARZ
# 217033      252654                                       Google Home
# 457416      745157                                           Netflix
# 220227      256146                                       The PCH App
# 257874      297863                                      CVS/pharmacy
# 730746     1523715  Sniper 3D Gun Shooter: Free Elite Shooting Games
# 283336      325565                     Sweatcoin Pays You To Get Fit
# 358692      511005                        Battle Royale: FPS Shooter
# 379812      547260                    Calorie Counter - MyFitnessPal
# 842270     1933979                    Calorie Counter - MyFitnessPal
# ...

# %%
#df_manual.to_csv('df_manual_evaluation.csv')

# %% [markdown]
# ### EDA

# %% [markdown]
# #### 1. Drop duplicates and record how many unique reviews are collected?

# %% [markdown]
# - 1142769 unique reviews are collected

# %% [markdown]
# #### 2. How many unique apps are in the dataset? How many apps in each of the 8 specified app categories?

# %% [markdown]
# - There are 87 unique apps in the dataset

# %% [markdown]
# - Category
# - Education         15
# - Entertainment     17
# - Family            15
# - Finance           13
# - Game_Action       13
# - Health_Fitness    12
# - Lifestyle         17
# - Music_Audio       16

# %% [markdown]
# #### 3. How many reviews exist in each of the eight app-categories?

# %% [markdown]
# - Category
# - Education          95936
# - Entertainment     184300
# - Family            125543
# - Finance           141238
# - Game_Action       209535
# - Health_Fitness    110035
# - Lifestyle         103097
# - Music_Audio       173085

# %% [markdown]
# #### 4. Based on the contentRating column in the details files for each app, what are the different contentRating groups in each app-category?

# %% [markdown]
# - Education: Everyone
# - Entertainment: Teen, Everyone, Mature 17+
# - Family: Everyone 10+, Everyone
# - Finance: Everyone
# - Game_Action: Everyone, Teen, Mature 17+
# - Health_Fitness: Everyone
# - Lifestyle: Everyone, Mature 17+, Teen
# - Music_Audio: Teen, Everyone

# %% [markdown]
# #### 5. How many apps exist in each of these contentRating-sub-groups in each app-category?

# %%
Image(filename='data542_project_Q5.png')

# %% [markdown]
# #### 6. How many reviews in each contentRating-sub-groups in each app-category?

# %%
Image(filename='data542_project_Q6.png')

# %% [markdown]
# #### 7. Should we remove the reviews that contain two or less number of words?

# %% [markdown]
#     a. Justify your answers.
#         -> In my opinion, it is recommended to remove reviews that contain two or less number of words because most of the english words two or less number of words are verbs or prepositions which are too ambiguous for considering as reviews.
#
#     b. Can we remove the reviews with two or less words for some score-sub-groups and keep them in the other ones? E.g. if the review has score 1, we should remove such reviews, but we should keep them if the rating is 5. Justify your answers.
#          -> I do not think we can remove them because I believe 'text' column and 'score' column should be analyzed separately. Removing reviews that contain two or less number of words can be removed because they are irrelevant for analysis. However, 'score' is very important for the analysis because removing lowest scores would affect the descriptive statistics and further analysis. Therefore, I would keep both score 1 and 5.

# %% [markdown]
# #### 8. How many reviews exist in each of the eight app-categories? Compare with question 3.

# %%
#Q3
Image(filename='data542_project_Q3.png')

# %%
#Q8
Image(filename='data542_project_Q8.png')

# %% [markdown]
# #### 9. How many reviews in each contentRating-sub-groups in each app-category? Compare with question 6.

# %%
Image(filename='data542_project_Q9.png')

# %% [markdown]
# #### 10. What is the number of reviews for each score (score column)? For example, 35000 reviews have a score of 1, etc.

# %%
Image(filename='data542_project_Q10.png')

# %% [markdown]
# #### 11. How many apps exist in each score-sub-group?

# %%
Image(filename='data542_project_Q11.png')

# %% [markdown]
# #### 12. Compare the number of reviews for each score in a plot (Remember to normalize the numbers when you are comparing them).

# %%
Image(filename='data542_project_Q12.png')

# %% [markdown]
# #### 13. What is the average length of the reviews in each score-sub-group?

# %%
Image(filename='data542_project_Q13.png')

# %% [markdown]
# #### 14. Compare the average length of reviews in each score-sub-group in the 8 app categories (draw a plot).

# %%
Image(filename='data542_project_Q14.png')

# %% [markdown]
# #### 15. Compare the number of reviews in each score-sub-group in the 8 app categories (draw a plot).

# %%
Image(filename='data542_project_Q15.png')

# %% [markdown]
# #### 16. Compare the number of apps in each score-sub-group in the 8 app categories (draw a plot).

# %%
Image(filename='data542_project_Q16.png')

# %% [markdown]
# #### 17. Is there any correlation between the length of the reviews and the score in each app-category?

# %%
Image(filename='data542_project_Q17.png')

# %% [markdown]
# #### 18. Find the evolution/changes of the star rating and length of reviews during time for each app category. Draw plots.

# %% [markdown]
#     a. Can we use the date column for this question?
#         -> Yes, it is wise to use the date column as the question is asking to find the evolution of the rating and length of reviews during time for each app category.
#
#     b. If not, what is the solution based on the data you have?
#         -> If we are not using the date column, it would provide really unreliable output. However, it is not impossible. We can use percentages to find the changes of the star rating and length of reviews.

# %%
Image(filename='data542_project_Q18.png')

# %% [markdown]
# #### 19. Compare your scores among the app categories. Do you see a difference between app categories?

# %%
manual = pd.read_csv('df_manual_evaluation.csv')
manual.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                        appTitle      userName  \
# 0      194766        225696                    YouTube Kids   Joseph Rich
# 1      179852        208176                         Netflix           NaN
# 2      164965        190724  Hulu: Stream TV, Movies & more       A. West
# 3      724532       1503776                        Cash App  Mary Johnson
# 4      699032       1416015               Google Play Games  Sohnish more
#
#          date  score                                               text  \
# 0  2019-03-02      1                                           It sucks
# 1  2019-03-10      1  this app is scandalous it says there needs to ...
# 2  2019-03-07      1  What a crock they charge a monthly fee and you...
# 3  2019-04-07      1  DO NOT DOWN LOAD THIS APP THEY HOLD YOUR MONEY...
# 4  2019-04-11      1                                    sign up problem
#
#         Category contentRating  review_length date_month  Sentiment  \
# ...

# %%
pd.DataFrame(manual.groupby(['Category'])['Constructive'].count()).plot(kind = 'bar')
plt.show()

# %% [markdown]
# - I definitely see a difference among app categories. It seems Entertainment is the top category with highest score. Next is Game_Action. Education and Finance categories have the lowest scores.
